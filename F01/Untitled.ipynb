# %%
import cymetric as cym

# %%
db = cym.dbopen("0.h5")
ev = cym.Evaluator(db)

# %%
from cymetric import graphs

# %%
graphs.flow_graph(ev)

# %%
from cymetric import timeseries as tm

# %%
def get_nuc_frac(nuc):
    df = tm.transactions(ev, senders=['lwr'], nucs=nuc )
    df = df[df['Mass'] > 0 ]

    tot = tm.transactions(ev, senders=['lwr']) 
    tot = tot[tot['Mass'] > 0 ]                

    df['Mass'] = df['Mass']/tot['Mass']
    print(df.iloc[2]['Mass'])

# %%
get_nuc_frac(['238pu'])
# Out:
# 0.0023490009989046144

# %%
get_nuc_frac(['239pu'])
# Out:
# 0.022922525660671152

# %%
get_nuc_frac(['240pu'])
# Out:
# 0.01671721358030397

# %%
get_nuc_frac(['241pu'])
# Out:
# 0.010363463387476497

# %%
get_nuc_frac(['242pu'])
# Out:
# 0.007420333620555439
